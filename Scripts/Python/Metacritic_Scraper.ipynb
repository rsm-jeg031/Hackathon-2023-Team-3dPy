# %% [markdown]
# # Metacritic Scraper for PlayStation Posts 🎮
#
# **https://www.metacritic.com/robots.txt**

# %%
import requests as re
import json as json 
import os as os
from bs4 import BeautifulSoup as bs 
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %% [markdown]
# page number to go back one year is 90 (~ 15 ish dec 2022)

# %%
def article_scraper(page_number):
    url = f'https://www.metacritic.com/browse/game/all/all/all-time/new/?releaseYearMin=1958&releaseYearMax=2023&platform=ps5&platform=ps4&page={page_number}'
    headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7)"}  # metacritic blocks default user agent so I needed to tell it it's me 🤷‍♂️
    response = re.get(url, headers=headers)
    if response.status_code != 200:
        raise Exception(f"Status code: {response.status_code}")  # since they block default user agents, I needed to check to make sure the request went through 👺
    soup = bs(response.content, 'html.parser')

    games = soup.find_all('div', class_='c-finderProductCard')
    data = []
    for game in games:
        link_element = game.find('a', class_='c-finderProductCard_container')
        title_element = game.find('h3', class_='c-finderProductCard_titleHeading')
        date_element = game.find('div', class_='c-finderProductCard_meta').find('span')
        description_element = game.find('div', class_='c-finderProductCard_description').find('span')

        link = f"https://www.metacritic.com{link_element['href']}" if link_element else None
        title = title_element.get_text(strip=True) if title_element else None
        date = date_element.get_text(strip=True) if date_element else None
        description = description_element.get_text(strip=True) if description_element else None
        
        data.append({'Title': title, 'Release Date': date, 'Description': description, 'Game Link': link})
    return data


N = 1  # Manually adjust number of pages to scrape
all_data = []
for page in range(1, N + 1):
    print(f"Scraping page {page}...")
    all_data.extend(article_scraper(page))

df = pd.DataFrame(all_data)

print(df)
# Out:
# Scraping page 1...
#                                                 Title  Release Date  \
# 0                                           Railbreak  Dec 22, 2023
# 1                                     Synthetic Lover  Dec 22, 2023
# 2                              Three Minutes To Eight  Dec 21, 2023
# 3                           Mortal Kombat 1: Quan Chi  Dec 21, 2023
# 4                                         Tiger Blade  Dec 20, 2023
# 5                                  3D Color Labyrinth  Dec 20, 2023
# 6                                   Bigfoot's Journey  Dec 20, 2023
# 7          Rhapsody II: Ballad of the Little Princess  Dec 20, 2023
# 8                                         Hotel R'n'R  Dec 20, 2023
# 9      Aokana: Four Rhythms Across the Blue - EXTRA1P  Dec 20, 2023
# 10                                      Vetrix Worlds  Dec 20, 2023
# 11                           Poppy Playtime Chapter 1  Dec 20, 2023
# 12             Rhapsody III: Memories of Marl Kingdom  Dec 20, 2023
# 13                                            Draco D  Dec 20, 2023
# 14                                           DARKGEMS  Dec 20, 2023
# 15  Pajama Sam: You are What you Eat from Your Hea...  Dec 20, 2023
# 16                                         SokoWinter  Dec 20, 2023
# 17                             Rail Romanesque Origin  Dec 20, 2023
# 18     Asonde Shogi ga Tsuyoku Naru! Ginsei Shogi DX2  Dec 20, 2023
# 19                                   This Bed We Made  Dec 20, 2023
# 20                                 Aery - Calm Mind 4  Dec 20, 2023
# 21  Freddi Fish 4: The Case of the Hogfish Rustler...  Dec 20, 2023
# 22                                  D.C.5 ~Da Capo 5~  Dec 20, 2023
# 23                      Ravva and the Phantom Library  Dec 20, 2023
#
#                                           Description  \
# 0   Power through hordes of zombies, '90s arcade s...
# 1   In the year 2066, biologically engineered huma...
# 2   Set in the near future, Three Minutes To Eight...
# 3   Quan Chi hasn't been a playable character in a...
# 4   Tiger Blade brings all the stylish, adrenaline...
# 5
# 6
# 7   Join Kururu on her journey to find true love a...
# 8   You are a failed musician who makes a deal wit...
# 9
# 10  The critically acclaimed Tetris-inspired VR Pu...
# 11
# 12  Dive back into Marl Kingdom through a series o...
# 13
# 14  DARKGEMS is a cartoony mining rogue-lite game ...
# 15  You're playing Sam who once again assumes the ...
# 16  SokoWinter is a sokoban game with slippery flo...
# 17
# 18  Shogi software with functions that even beginn...
# 19  February 17, 1958. Sophie's shift at the Clari...
# 20  Aery - Calm Mind 4 is an interactive game expe...
# 21  Hey Partner, Freddi Fish and Luther need your ...
# 22  Kakamijima, the island closest to the sky. On ...
# 23  Ravva and the Phantom Library is a pixel-art p...
#
#                                             Game Link
# 0          https://www.metacritic.com/game/railbreak/
# 1    https://www.metacritic.com/game/synthetic-lover/
# 2   https://www.metacritic.com/game/three-minutes-...
# 3   https://www.metacritic.com/game/mortal-kombat-...
# 4        https://www.metacritic.com/game/tiger-blade/
# 5   https://www.metacritic.com/game/3d-color-labyr...
# 6   https://www.metacritic.com/game/bigfoots-journey/
# 7   https://www.metacritic.com/game/rhapsody-ii-ba...
# 8          https://www.metacritic.com/game/hotel-rnr/
# 9   https://www.metacritic.com/game/aokana-four-rh...
# 10     https://www.metacritic.com/game/vetrix-worlds/
# 11  https://www.metacritic.com/game/poppy-playtime...
# 12  https://www.metacritic.com/game/rhapsody-iii-m...
# 13           https://www.metacritic.com/game/draco-d/
# 14          https://www.metacritic.com/game/darkgems/
# 15  https://www.metacritic.com/game/pajama-sam-you...
# 16        https://www.metacritic.com/game/sokowinter/
# 17  https://www.metacritic.com/game/rail-romanesqu...
# 18  https://www.metacritic.com/game/asonde-shogi-g...
# 19  https://www.metacritic.com/game/this-bed-we-made/
# 20  https://www.metacritic.com/game/aery-calm-mind-4/
# 21  https://www.metacritic.com/game/freddi-fish-4-...
# 22     https://www.metacritic.com/game/dc5-da-capo-5/
# 23  https://www.metacritic.com/game/ravva-and-the-...

# %%
def comments_spider(df):
    driver = webdriver.Chrome()
    total_games = len(df)
    comments_data = []

    for index, (game_index, game_row) in enumerate(df.iterrows(), start=1):
        game_link = game_row['Game Link']
        game_title = game_link.split('/')[-2].replace('-', ' ')

        print(f"{index}/{total_games}: Processing {game_title} at {game_link}")
        driver.get(game_link)

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(3) 

            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        soup = bs(driver.page_source, 'html.parser')
        critic_reviews = soup.find_all('div', class_='c-reviewsSection_criticReviews')
        user_reviews = soup.find_all('div', class_='c-reviewsSection_userReviews')
        num_critic_comments = len([element for element in critic_reviews if element.find('div', class_='c-siteReview_quote')])
        num_user_comments = len([element for element in user_reviews if element.find('div', class_='c-siteReview_quote')])
        num_comments = num_critic_comments + num_user_comments
        
        print(f"🔎 -- Found {num_comments} reviews for {game_title} -- 🔍")

        for review in critic_reviews + user_reviews:
            console_element = review.find('a', class_='c-siteReview_platform')
            console_type = console_element.get_text(strip=True) if console_element else 'null'

            commenter_name_element = review.find('a', class_='c-siteReviewHeader_username')
            if commenter_name_element:
                commenter_name = commenter_name_element.get_text(strip=True)
            else:
                commenter_name_element = review.find('a', class_='c-siteReviewHeader_publicationName')
                commenter_name = commenter_name_element.get_text(strip=True) if commenter_name_element else 'null'

            reviewer_type = 'Critic' if review in critic_reviews else 'User'

            comment_element = review.find('div', class_='c-siteReview_quote')
            comment_text = comment_element.span.get_text(strip=True) if comment_element and comment_element.span else 'null'

            date_element = review.find('div', class_='c-siteReviewHeader_reviewDate')
            date_commented = date_element.get_text(strip=True) if date_element else 'null'

            score_element = review.find('div', class_='c-siteReviewScore')
            score_number = score_element.span.get_text(strip=True) if score_element and score_element.span else 'null'

            comment_data = {
                'Game Title': game_title,
                'Console': console_type,
                'Commenter Name': commenter_name,
                'Reviewer Type': reviewer_type,
                'Comment': comment_text,
                'Date Commented': date_commented,
                'Score Number': score_number
            }
            comments_data.append(comment_data)

    driver.quit()
    comments_df = pd.DataFrame(comments_data)
    return comments_df

raw_comments_df = comments_spider(df)
print(raw_comments_df)
# Out:
# 1/24: Processing railbreak at https://www.metacritic.com/game/railbreak/
# 🔎 -- Found 0 reviews for railbreak -- 🔍
# 2/24: Processing synthetic lover at https://www.metacritic.com/game/synthetic-lover/
# 🔎 -- Found 0 reviews for synthetic lover -- 🔍
# 3/24: Processing three minutes to eight at https://www.metacritic.com/game/three-minutes-to-eight/
# 🔎 -- Found 1 reviews for three minutes to eight -- 🔍
# 4/24: Processing mortal kombat 1 quan chi at https://www.metacritic.com/game/mortal-kombat-1-quan-chi/
# 🔎 -- Found 0 reviews for mortal kombat 1 quan chi -- 🔍
# 5/24: Processing tiger blade at https://www.metacritic.com/game/tiger-blade/
# 🔎 -- Found 1 reviews for tiger blade -- 🔍
# 6/24: Processing 3d color labyrinth at https://www.metacritic.com/game/3d-color-labyrinth/
# 🔎 -- Found 0 reviews for 3d color labyrinth -- 🔍
# 7/24: Processing bigfoots journey at https://www.metacritic.com/game/bigfoots-journey/
# 🔎 -- Found 0 reviews for bigfoots journey -- 🔍
# 8/24: Processing rhapsody ii ballad of the little princess at https://www.metacritic.com/game/rhapsody-ii-ballad-of-the-little-princess/
# 🔎 -- Found 1 reviews for rhapsody ii ballad of the little princess -- 🔍
# 9/24: Processing hotel rnr at https://www.metacritic.com/game/hotel-rnr/
# 🔎 -- Found 1 reviews for hotel rnr -- 🔍
# 10/24: Processing aokana four rhythms across the blue extra1p at https://www.metacritic.com/game/aokana-four-rhythms-across-the-blue-extra1p/
# 🔎 -- Found 0 reviews for aokana four rhythms across the blue extra1p -- 🔍
# 11/24: Processing vetrix worlds at https://www.metacritic.com/game/vetrix-worlds/
# 🔎 -- Found 0 reviews for vetrix worlds -- 🔍
# 12/24: Processing poppy playtime chapter 1 at https://www.metacritic.com/game/poppy-playtime-chapter-1/
# 🔎 -- Found 1 reviews for poppy playtime chapter 1 -- 🔍
# 13/24: Processing rhapsody iii memories of marl kingdom at https://www.metacritic.com/game/rhapsody-iii-memories-of-marl-kingdom/
# 🔎 -- Found 0 reviews for rhapsody iii memories of marl kingdom -- 🔍
# 14/24: Processing draco d at https://www.metacritic.com/game/draco-d/
# 🔎 -- Found 0 reviews for draco d -- 🔍
# 15/24: Processing darkgems at https://www.metacritic.com/game/darkgems/
# 🔎 -- Found 0 reviews for darkgems -- 🔍
# 16/24: Processing pajama sam you are what you eat from your head to at https://www.metacritic.com/game/pajama-sam-you-are-what-you-eat-from-your-head-to/
# 🔎 -- Found 0 reviews for pajama sam you are what you eat from your head to -- 🔍
# 17/24: Processing sokowinter at https://www.metacritic.com/game/sokowinter/
# 🔎 -- Found 0 reviews for sokowinter -- 🔍
# 18/24: Processing rail romanesque origin at https://www.metacritic.com/game/rail-romanesque-origin/
# 🔎 -- Found 0 reviews for rail romanesque origin -- 🔍
# 19/24: Processing asonde shogi ga tsuyoku naru ginsei shogi dx2 at https://www.metacritic.com/game/asonde-shogi-ga-tsuyoku-naru-ginsei-shogi-dx2/
# 🔎 -- Found 0 reviews for asonde shogi ga tsuyoku naru ginsei shogi dx2 -- 🔍
# 20/24: Processing this bed we made at https://www.metacritic.com/game/this-bed-we-made/
# 🔎 -- Found 1 reviews for this bed we made -- 🔍
# 21/24: Processing aery calm mind 4 at https://www.metacritic.com/game/aery-calm-mind-4/
# 🔎 -- Found 0 reviews for aery calm mind 4 -- 🔍
# 22/24: Processing freddi fish 4 the hogfish rustlers of briny gulch at https://www.metacritic.com/game/freddi-fish-4-the-hogfish-rustlers-of-briny-gulch/
# 🔎 -- Found 0 reviews for freddi fish 4 the hogfish rustlers of briny gulch -- 🔍
# 23/24: Processing dc5 da capo 5 at https://www.metacritic.com/game/dc5-da-capo-5/
# 🔎 -- Found 0 reviews for dc5 da capo 5 -- 🔍
# 24/24: Processing ravva and the phantom library at https://www.metacritic.com/game/ravva-and-the-phantom-library/
# 🔎 -- Found 0 reviews for ravva and the phantom library -- 🔍
#                                            Game Title            Console  \
# 0                                           railbreak               null
# 1                                           railbreak               null
# 2                                     synthetic lover               null
# 3                                     synthetic lover               null
# 4                              three minutes to eight                 PC
# 5                              three minutes to eight               null
# 6                            mortal kombat 1 quan chi               null
# 7                            mortal kombat 1 quan chi               null
# 8                                         tiger blade      PlayStation 5
# 9                                         tiger blade               null
# 10                                 3d color labyrinth               null
# 11                                 3d color labyrinth               null
# 12                                   bigfoots journey               null
# 13                                   bigfoots journey               null
# 14          rhapsody ii ballad of the little princess                 PC
# 15          rhapsody ii ballad of the little princess               null
# 16                                          hotel rnr      PlayStation 4
# 17                                          hotel rnr               null
# 18        aokana four rhythms across the blue extra1p               null
# 19        aokana four rhythms across the blue extra1p               null
# 20                                      vetrix worlds               null
# 21                                      vetrix worlds               null
# 22                           poppy playtime chapter 1  iOS (iPhone/iPad)
# 23                           poppy playtime chapter 1               null
# 24                           poppy playtime chapter 1               null
# 25              rhapsody iii memories of marl kingdom               null
# 26              rhapsody iii memories of marl kingdom               null
# 27                                            draco d               null
# 28                                            draco d               null
# 29                                           darkgems               null
# 30                                           darkgems               null
# 31  pajama sam you are what you eat from your head to               null
# 32  pajama sam you are what you eat from your head to               null
# 33                                         sokowinter               null
# 34                                         sokowinter               null
# 35                             rail romanesque origin               null
# 36                             rail romanesque origin               null
# 37      asonde shogi ga tsuyoku naru ginsei shogi dx2               null
# 38      asonde shogi ga tsuyoku naru ginsei shogi dx2               null
# 39                                   this bed we made      PlayStation 5
# 40                                   this bed we made               null
# 41                                   this bed we made               null
# 42                                   aery calm mind 4               null
# 43                                   aery calm mind 4               null
# 44  freddi fish 4 the hogfish rustlers of briny gulch               null
# 45  freddi fish 4 the hogfish rustlers of briny gulch               null
# 46                                      dc5 da capo 5               null
# 47                                      dc5 da capo 5               null
# 48                      ravva and the phantom library               null
# 49                      ravva and the phantom library               null
#
#           Commenter Name Reviewer Type  \
# 0                   null        Critic
# 1                   null          User
# 2                   null        Critic
# 3                   null          User
# 4       Adventure Gamers        Critic
# 5                   null          User
# 6                   null        Critic
# 7                   null          User
# 8    Gamereactor Finland        Critic
# 9                   null          User
# 10                  null        Critic
# 11                  null          User
# 12                  null        Critic
# 13                  null          User
# 14               RPG Fan        Critic
# 15                  null          User
# 16  PlayStation Universe        Critic
# 17                  null          User
# 18                  null        Critic
# 19                  null          User
# 20                  null        Critic
# 21                  null          User
# 22        Pocket Tactics        Critic
# 23                  null          User
# 24                  null          User
# 25                  null        Critic
# 26                  null          User
# 27                  null        Critic
# 28                  null          User
# 29                  null        Critic
# 30                  null          User
# 31                  null        Critic
# 32                  null          User
# 33                  null        Critic
# 34                  null          User
# 35                  null        Critic
# 36                  null          User
# 37                  null        Critic
# 38                  null          User
# 39  PlayStation Universe        Critic
# 40                  null          User
# 41                  null          User
# 42                  null        Critic
# 43                  null          User
# 44                  null        Critic
# 45                  null          User
# 46                  null        Critic
# 47                  null          User
# 48                  null        Critic
# 49                  null          User
#
#                                               Comment Date Commented  \
# 0                                                null           null
# 1                                                null           null
# 2                                                null           null
# 3                                                null           null
# 4   The gripping science-fiction narrative in Thre...   Nov 29, 2023
# 5                                                null           null
# 6                                                null           null
# 7                                                null           null
# 8    It's not fun to always learn by trial and error.   Dec 19, 2023
# 9                                                null           null
# 10                                               null           null
# 11                                               null           null
# 12                                               null           null
# 13                                               null           null
# 14  It’s unfortunate that it took over twenty year...   Aug 24, 2023
# 15                                               null           null
# 16  Hotel R’n’R allows players to engage in an ult...    Jun 3, 2020
# 17                                               null           null
# 18                                               null           null
# 19                                               null           null
# 20                                               null           null
# 21                                               null           null
# 22  Poppy Playtime Chapter 1 ushers in a new era o...    Oct 5, 2023
# 23                                               null           null
# 24                                               null           null
# 25                                               null           null
# 26                                               null           null
# 27                                               null           null
# 28                                               null           null
# 29                                               null           null
# 30                                               null           null
# 31                                               null           null
# 32                                               null           null
# 33                                               null           null
# 34                                               null           null
# 35                                               null           null
# 36                                               null           null
# 37                                               null           null
# 38                                               null           null
# 39  This Bed We Made is a great game that kept me ...    Nov 4, 2023
# 40                                               null           null
# 41                                               null           null
# 42                                               null           null
# 43                                               null           null
# 44                                               null           null
# 45                                               null           null
# 46                                               null           null
# 47                                               null           null
# 48                                               null           null
# 49                                               null           null
#
#    Score Number
# 0           tbd
# 1          null
# 2           tbd
# 3          null
# 4           100
# 5          null
# 6           tbd
# 7          null
# 8            50
# 9          null
# 10          tbd
# 11         null
# 12          tbd
# 13         null
# 14           80
# 15         null
# 16           85
# 17         null
# 18          tbd
# 19         null
# 20          tbd
# 21          tbd
# 22           70
# 23          7.0
# 24         null
# 25          tbd
# 26         null
# 27          tbd
# 28         null
# 29          tbd
# 30         null
# 31          tbd
# 32         null
# 33          tbd
# 34         null
# 35          tbd
# 36         null
# 37          tbd
# 38         null
# 39           80
# 40          7.8
# 41         null
# 42          tbd
# 43         null
# 44          tbd
# 45          tbd
# 46          tbd
# 47         null
# 48          tbd
# 49         null

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### Lab Testing Area 🔍👨‍⚕️

# %%
from itables import show

# %%
print(raw_comments_df.shape)
# Out:
# (50, 7)

# %%
show(raw_comments_df)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="bf950fbb-72a5-463f-a3b5-c13f644cc92e" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>Game Title</th>
#       <th>Console</th>
#       <th>Commenter Name</th>
#       <th>Reviewer Type</th>
#       <th>Comment</th>
#       <th>Date Commented</th>
#       <th>Score Number</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [["railbreak", "null", "null", "Critic", "null", "null", "tbd"], ["railbreak", "null", "null", "User", "null", "null", "null"], ["synthetic lover", "null", "null", "Critic", "null", "null", "tbd"], ["synthetic lover", "null", "null", "User", "null", "null", "null"], ["three minutes to eight", "PC", "Adventure Gamers", "Critic", "The gripping science-fiction narrative in Three Minutes To Eight features an ingenious use of random elements that, combined with well-executed pixel art graphics and accomplished voice acting, ensure that each experience is unique.", "Nov 29, 2023", "100"], ["three minutes to eight", "null", "null", "User", "null", "null", "null"], ["mortal kombat 1 quan chi", "null", "null", "Critic", "null", "null", "tbd"], ["mortal kombat 1 quan chi", "null", "null", "User", "null", "null", "null"], ["tiger blade", "PlayStation 5", "Gamereactor Finland", "Critic", "It's not fun to always learn by trial and error.", "Dec 19, 2023", "50"], ["tiger blade", "null", "null", "User", "null", "null", "null"], ["3d color labyrinth", "null", "null", "Critic", "null", "null", "tbd"], ["3d color labyrinth", "null", "null", "User", "null", "null", "null"], ["bigfoots journey", "null", "null", "Critic", "null", "null", "tbd"], ["bigfoots journey", "null", "null", "User", "null", "null", "null"], ["rhapsody ii ballad of the little princess", "PC", "RPG Fan", "Critic", "It\u2019s unfortunate that it took over twenty years for the West to experience Rhapsody II properly, as the game is incredibly fun, amusing, and full of both heart and charm. The characters are just as hilarious as they are heartfelt, the musical numbers make the game stand out amongst its peers, and the game is wildly creative in every aspect. Rhapsody II\u2018s short length ensures it\u2019s a breezy experience and a perfect palette cleanser amidst the sea of RPGs set in miserable worlds. Rhapsody II is a vastly improved sequel on all fronts, and while it has a few minor blemishes, it\u2019s easy to recommend to anyone looking for a unique experience.", "Aug 24, 2023", "80"], ["rhapsody ii ballad of the little princess", "null", "null", "User", "null", "null", "null"], ["hotel rnr", "PlayStation 4", "PlayStation Universe", "Critic", "Hotel R\u2019n\u2019R allows players to engage in an ultimate fantasy \u2013 being a rock star and smashing up a hotel room. With solid controls and a fun game loop, Hotel R\u2019n\u2019R will call players back again and again for one more round \u2013 even if the progression feels a bit slow. This is a solid game with a wicked sense of humor. If you suspect that you will like Hotel R\u2019n\u2019R even a little, I\u2019m here to tell you that you will love it. Rock on.", "Jun 3, 2020", "85"], ["hotel rnr", "null", "null", "User", "null", "null", "null"], ["aokana four rhythms across the blue extra1p", "null", "null", "Critic", "null", "null", "tbd"], ["aokana four rhythms across the blue extra1p", "null", "null", "User", "null", "null", "null"], ["vetrix worlds", "null", "null", "Critic", "null", "null", "tbd"], ["vetrix worlds", "null", "null", "User", "null", "null", "tbd"], ["poppy playtime chapter 1", "iOS (iPhone/iPad)", "Pocket Tactics", "Critic", "Poppy Playtime Chapter 1 ushers in a new era of horror games, though it remains true to iconic tropes from the genre, thanks to its use of jump scares and puzzles. Unfortunately, on mobile the game suffers from some performance issues that may hinder your time with the game. Still, the atmosphere and story are enough to keep you hooked. Or, you could play it on PC, where we would score it higher than a seven.", "Oct 5, 2023", "70"], ["poppy playtime chapter 1", "null", "null", "User", "null", "null", "7.0"], ["poppy playtime chapter 1", "null", "null", "User", "null", "null", "null"], ["rhapsody iii memories of marl kingdom", "null", "null", "Critic", "null", "null", "tbd"], ["rhapsody iii memories of marl kingdom", "null", "null", "User", "null", "null", "null"],  ...
#
#     // Define the dt_args
#     let dt_args = {"order": []};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#bf950fbb-72a5-463f-a3b5-c13f644cc92e').DataTable(dt_args);
#     });
# </script>
# </div>
